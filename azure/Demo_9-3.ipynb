# %% [markdown]
# # 印刷文字辨識服務操作

# %%
from azure.cognitiveservices.vision.computervision import ComputerVisionClient
from azure.cognitiveservices.vision.computervision.models import TextOperationStatusCodes
from msrest.authentication import CognitiveServicesCredentials
import time

# Set API key.
subscription_key = '2ed35306c8614c51ab8b9a880ae87f98'
# Set endpoint.
endpoint = 'https://vicbosstvv.cognitiveservices.azure.com/'
# Call API
computervision_client = ComputerVisionClient(endpoint, CognitiveServicesCredentials(subscription_key))

'''
Batch Read File, recognize printed text - remote
This example will extract printed text in an image, then print results, line by line.
This API call can also recognize handwriting (not shown).
'''
print("===== Batch Read File - remote =====")
# Get an image with printed text
remote_image_printed_text_url = "https://raw.githubusercontent.com/Azure-Samples/cognitive-services-sample-data-files/master/ComputerVision/Images/printed_text.jpg"

# Call API with URL and raw response (allows you to get the operation location)
recognize_printed_results = computervision_client.batch_read_file(remote_image_printed_text_url,  raw=True)

# Get the operation location (URL with an ID at the end) from the response
operation_location_remote = recognize_printed_results.headers["Operation-Location"]
# Grab the ID from the URL
operation_id = operation_location_remote.split("/")[-1]

# Call the "GET" API and wait for it to retrieve the results 
while True:
    get_printed_text_results = computervision_client.get_read_operation_result(operation_id)
    if get_printed_text_results.status not in ['NotStarted', 'Running']:
        break
    time.sleep(1)

# Print the detected text, line by line
if get_printed_text_results.status == TextOperationStatusCodes.succeeded:
    for text_result in get_printed_text_results.recognition_results:
        for line in text_result.lines:
            print(line.text)
            print(line.bounding_box)
print()
# Out:
# ===== Batch Read File - remote =====
# Nutrition Facts Amount Per Serving
# [145.0, 0.0, 1239.0, 212.0, 1225.0, 280.0, 131.0, 58.0]
# Serving size: 1 bar (40g)
# [110.0, 59.0, 598.0, 157.0, 587.0, 207.0, 100.0, 109.0]
# Serving Per Package: 4
# [83.0, 108.0, 549.0, 206.0, 538.0, 256.0, 73.0, 158.0]
# Total Fat 13g
# [683.0, 214.0, 1001.0, 287.0, 990.0, 333.0, 673.0, 260.0]
# Saturated Fat 1.5g
# [695.0, 296.0, 1121.0, 395.0, 1108.0, 448.0, 683.0, 348.0]
# Amount Per Serving
# [29.0, 208.0, 491.0, 310.0, 478.0, 368.0, 17.0, 266.0]
# Trans Fat 0g
# [668.0, 364.0, 954.0, 435.0, 941.0, 488.0, 655.0, 417.0]
# alories 190
# [9.0, 293.0, 265.0, 350.0, 255.0, 397.0, 0.0, 340.0]
# Cholesterol Omg
# [593.0, 425.0, 1007.0, 527.0, 994.0, 581.0, 580.0, 480.0]
# ories from Fat 110
# [9.0, 377.0, 399.0, 465.0, 389.0, 509.0, 0.0, 422.0]
# Sodium 20mg
# [562.0, 497.0, 914.0, 588.0, 899.0, 644.0, 548.0, 553.0]
# nt Daily Values are based on
# [8.0, 477.0, 521.0, 599.0, 511.0, 641.0, 0.0, 518.0]
# Vitamin A 50%
# [525.0, 598.0, 776.0, 657.0, 766.0, 700.0, 515.0, 640.0]
# calorie diet.
# [13.0, 535.0, 196.0, 576.0, 187.0, 616.0, 4.0, 574.0]

# %%
from azure.cognitiveservices.vision.computervision import ComputerVisionClient
from azure.cognitiveservices.vision.computervision.models import TextOperationStatusCodes
from msrest.authentication import CognitiveServicesCredentials
import time

# Set API key.
subscription_key = '2ed35306c8614c51ab8b9a880ae87f98'
# Set endpoint.
endpoint = 'https://vicbosstvv.cognitiveservices.azure.com/'
# Call API
computervision_client = ComputerVisionClient(endpoint, CognitiveServicesCredentials(subscription_key))


import os

# 指定圖檔
local_image_path = os.getcwd() + '/lato1.jpg'

# 讀取圖片
local_image = open(local_image_path, "rb")
'''
Batch Read File, recognize printed text - remote
This example will extract printed text in an image, then print results, line by line.
This API call can also recognize handwriting (not shown).
'''
print("===== Batch Read File - remote =====")
# Get an image with printed text
remote_image_printed_text_url = "https://raw.githubusercontent.com/Azure-Samples/cognitive-services-sample-data-files/master/ComputerVision/Images/printed_text.jpg"

# Call API with URL and raw response (allows you to get the operation location)
recognize_printed_results = computervision_client.batch_read_file_in_stream(local_image,  raw=True)

# Get the operation location (URL with an ID at the end) from the response
operation_location_remote = recognize_printed_results.headers["Operation-Location"]
# Grab the ID from the URL
operation_id = operation_location_remote.split("/")[-1]

# Call the "GET" API and wait for it to retrieve the results 
while True:
    get_printed_text_results = computervision_client.get_read_operation_result(operation_id)
    if get_printed_text_results.status not in ['NotStarted', 'Running']:
        break
    time.sleep(1)

# Print the detected text, line by line
if get_printed_text_results.status == TextOperationStatusCodes.succeeded:
    for text_result in get_printed_text_results.recognition_results:
        for line in text_result.lines:
            print(line.text)
            print(line.bounding_box)
print()
# Out:
# ===== Batch Read File - remote =====
# O
# [671.0, 371.0, 698.0, 372.0, 696.0, 395.0, 669.0, 394.0]
# 04141 87520 00029 08316 13416 94642 20119
# [132.0, 569.0, 969.0, 584.0, 968.0, 656.0, 131.0, 640.0]
# HI : 110/08/27Block
# [368.0, 667.0, 875.0, 686.0, 873.0, 734.0, 366.0, 715.0]
# HASU : #110000078 # 1 #JJ
# [308.0, 718.0, 769.0, 727.0, 768.0, 768.0, 308.0, 759.0]
# 1608
# [63.0, 765.0, 217.0, 770.0, 216.0, 821.0, 61.0, 817.0]
# 11 31 32 49
# [337.0, 776.0, 810.0, 785.0, 809.0, 827.0, 337.0, 818.0]
# 207 17 20 130/32 46
# [62.0, 819.0, 804.0, 829.0, 804.0, 875.0, 61.0, 865.0]
# BRIEF$50
# [886.0, 841.0, 1047.0, 847.0, 1046.0, 888.0, 884.0, 882.0]
# -PXJ
# [64.0, 872.0, 132.0, 871.0, 133.0, 905.0, 65.0, 904.0]
# MEETHINT$ 100
# [268.0, 889.0, 781.0, 896.0, 780.0, 933.0, 267.0, 926.0]
# JU JU: 110/08/26 22:54:52
# [270.0, 932.0, 801.0, 943.0, 800.0, 984.0, 269.0, 974.0]
# 1MRS: 24044074 BE: 240440741
# [227.0, 976.0, 858.0, 992.0, 857.0, 1033.0, 226.0, 1017.0]
# 000727079* TR: 0001282289 12944005700145246336
# [88.0, 1017.0, 980.0, 1045.0, 979.0, 1090.0, 87.0, 1062.0]

# %% [markdown]
# # 手寫文字辨識服務操作

# %%
from azure.cognitiveservices.vision.computervision import ComputerVisionClient
from azure.cognitiveservices.vision.computervision.models import TextOperationStatusCodes
from msrest.authentication import CognitiveServicesCredentials
import time

# Set API key.
subscription_key = '2ed35306c8614c51ab8b9a880ae87f98'
# Set endpoint.
endpoint = 'https://vicbosstvv.cognitiveservices.azure.com/'
# Call API
computervision_client = ComputerVisionClient(endpoint, CognitiveServicesCredentials(subscription_key))

'''
Batch Read File, recognize printed text - remote
This example will extract printed text in an image, then print results, line by line.
This API call can also recognize handwriting (not shown).
'''
print("===== Batch Read File - remote =====")
# Get an image with printed handwritten
remote_image_printed_text_url = "https://i.imgur.com/nDwHrQl.jpg"

# Call API with URL and raw response (allows you to get the operation location)
recognize_printed_results = computervision_client.batch_read_file(remote_image_printed_text_url,  raw=True)

# Get the operation location (URL with an ID at the end) from the response
operation_location_remote = recognize_printed_results.headers["Operation-Location"]
# Grab the ID from the URL
operation_id = operation_location_remote.split("/")[-1]

# Call the "GET" API and wait for it to retrieve the results 
while True:
    get_printed_text_results = computervision_client.get_read_operation_result(operation_id)
    if get_printed_text_results.status not in ['NotStarted', 'Running']:
        break
    time.sleep(1)

# Print the detected text, line by line
if get_printed_text_results.status == TextOperationStatusCodes.succeeded:
    for text_result in get_printed_text_results.recognition_results:
        for line in text_result.lines:
            print(line.text)
            print(line.bounding_box)
print()
# Out:
# ===== Batch Read File - remote =====
# O
# [671.0, 371.0, 698.0, 372.0, 696.0, 395.0, 669.0, 394.0]
# 04141 87520 00029 08316 13416 94642 20119
# [132.0, 569.0, 969.0, 584.0, 968.0, 656.0, 131.0, 640.0]
# HI : 110/08/27Block
# [368.0, 667.0, 875.0, 686.0, 873.0, 734.0, 366.0, 715.0]
# HASU : #110000078 # 1 #JJ
# [308.0, 718.0, 769.0, 727.0, 768.0, 768.0, 308.0, 759.0]
# 1608
# [63.0, 765.0, 217.0, 770.0, 216.0, 821.0, 61.0, 817.0]
# 11 31 32 49
# [337.0, 776.0, 810.0, 785.0, 809.0, 827.0, 337.0, 818.0]
# 207 17 20 130/32 46
# [62.0, 819.0, 804.0, 829.0, 804.0, 875.0, 61.0, 865.0]
# BRIEF$50
# [886.0, 841.0, 1047.0, 847.0, 1046.0, 888.0, 884.0, 882.0]
# -PXJ
# [64.0, 872.0, 132.0, 871.0, 133.0, 905.0, 65.0, 904.0]
# MEETHINT$ 100
# [268.0, 889.0, 781.0, 896.0, 780.0, 933.0, 267.0, 926.0]
# JU JU: 110/08/26 22:54:52
# [270.0, 932.0, 801.0, 943.0, 800.0, 984.0, 269.0, 974.0]
# 1MRS: 24044074 BE: 240440741
# [227.0, 976.0, 858.0, 992.0, 857.0, 1033.0, 226.0, 1017.0]
# 000727079* TR: 0001282289 12944005700145246336
# [88.0, 1017.0, 980.0, 1045.0, 979.0, 1090.0, 87.0, 1062.0]

# %%
from azure.cognitiveservices.vision.computervision import ComputerVisionClient
from azure.cognitiveservices.vision.computervision.models import TextOperationStatusCodes
from msrest.authentication import CognitiveServicesCredentials
import time

# Set API key.
subscription_key = '6ac220c316d24ff59df08be8d2096cf6'
# Set endpoint.
endpoint = 'https://vicbosstw.cognitiveservices.azure.com/'
# Call API
computervision_client = ComputerVisionClient(endpoint, CognitiveServicesCredentials(subscription_key))

'''
Batch Read File, recognize printed text - remote
This example will extract printed text in an image, then print results, line by line.
This API call can also recognize handwriting (not shown).
'''
print("===== Batch Read File - remote =====")
# Get an image with printed handwritten
remote_image_printed_text_url = "https://www.ocadu.ca/sites/default/files/documents/TUFF%2520Awards%2520Release%25202016.pdf"

# Call API with URL and raw response (allows you to get the operation location)
recognize_printed_results = computervision_client.batch_read_file(remote_image_printed_text_url,  raw=True)

# Get the operation location (URL with an ID at the end) from the response
operation_location_remote = recognize_printed_results.headers["Operation-Location"]
# Grab the ID from the URL
operation_id = operation_location_remote.split("/")[-1]

# Call the "GET" API and wait for it to retrieve the results 
while True:
    get_printed_text_results = computervision_client.get_read_operation_result(operation_id)
    if get_printed_text_results.status not in ['NotStarted', 'Running']:
        break
    time.sleep(1)

# Print the detected text, line by line
if get_printed_text_results.status == TextOperationStatusCodes.succeeded:
    for text_result in get_printed_text_results.recognition_results:
        for line in text_result.lines:
            print(line.text)
            print(line.bounding_box)
print()
# Out:
# ===== Batch Read File - remote =====
# TORONTO URBAN FILM FESTIVAL HOLDS 10th
# [1.1732, 0.7754, 7.349, 0.7644, 7.349, 1.0302, 1.1732, 1.0524]
# ANNIVERSARY AWARDS PARTY
# [2.1029, 1.1299, 6.3971, 1.1299, 6.3971, 1.3736, 2.1029, 1.3736]
# $20,000 IN CASH AND PRIZES AWARDED TO FILMMAKERS
# [1.4941, 1.5952, 7.0059, 1.5841, 7.0059, 1.7946, 1.4941, 1.7946]
# AT GLADSTONE HOTEL AWARDS CEREMONY
# [2.0807, 1.8389, 6.4082, 1.8499, 6.4082, 2.0383, 2.0807, 2.0383]
# ONE
# [2.0254, 2.6475, 2.5677, 2.7029, 2.5345, 2.9688, 2.0033, 2.8912]
# UTE.
# [2.9219, 2.7805, 3.3424, 2.8137, 3.3203, 3.0352, 2.8997, 3.0131]
# TEN
# [2.0254, 2.9688, 2.457, 2.9799, 2.4238, 3.2125, 2.0143, 3.2125]
# ARS.
# [2.8223, 3.0685, 3.2539, 3.0906, 3.2428, 3.3122, 2.8112, 3.279]
# Toronto
# [5.0247, 3.2457, 5.3457, 3.29, 5.3346, 3.4119, 5.0137, 3.3676]
# IMA
# [2.944, 3.3454, 3.3757, 3.3676, 3.3867, 3.578, 2.944, 3.578]
# Urbon
# [5.0137, 3.4008, 5.3568, 3.434, 5.3457, 3.5448, 5.0026, 3.5227]
# GLADSTONE
# [1.4277, 5.5609, 2.1914, 5.4723, 2.2135, 5.6163, 1.4499, 5.6939]
# HOTEL
# [1.5716, 5.6606, 2.0143, 5.6274, 2.0254, 5.7271, 1.5827, 5.7714]
# Cam Milne and lan Gadsby of Pattison Onestop present the Grand prize to SPENCER RYERSON and PETER WIDDRINGTON
# [1.1178, 5.8933, 7.4154, 5.8711, 7.4154, 6.004, 1.1178, 6.0151]
# TORONTO (September 20, 2016) - Toronto Urban Film Festival (TUFF), North America's largest
# [0.6973, 6.3917, 7.4043, 6.3917, 7.4043, 6.569, 0.6973, 6.569]
# commuter film festival, celebrated its successful 10th edition with an awards ceremony hosted at the
# [0.6751, 6.5911, 7.4486, 6.6022, 7.4486, 6.7573, 0.6751, 6.7573]
# Gladstone Hotel on Sunday night. Over $20,000 in cash and prizes was awarded to talented filmmakers
# [0.6862, 6.7684, 7.7253, 6.7684, 7.7253, 6.9345, 0.6862, 6.9345]
# from Canada and across the globe. TUFF cofounder and Director Sharon Switzer, President of
# [0.6641, 6.9456, 7.1387, 6.9456, 7.1387, 7.1118, 0.6641, 7.1118]
# PATTISON Outdoor Randy Otto, and Vice President/General Manager of PATTISON Onestop Cam
# [0.6973, 7.1118, 7.6699, 7.1229, 7.6699, 7.289, 0.6973, 7.289]
# Milne spoke at the ceremony that culminated in its first prize (selected by TUFF 2016 guest judge and
# [0.6862, 7.3223, 7.5924, 7.3223, 7.5924, 7.4773, 0.6862, 7.4773]
# Toronto Film Commissioner Zaib Shaikh) of $3000 cash from Pattison Onestop and a permanent license
# [0.6973, 7.4884, 7.7917, 7.4995, 7.7917, 7.6657, 0.6973, 7.6546]
# for Storyboard Pro software from Toon Boom Animation being awarded to Torontonians Spencer
# [0.6751, 7.6657, 7.2272, 7.6657, 7.2272, 7.8318, 0.6751, 7.8318]
# Ryerson and Peter Widdrington for their short film A NEW HOME.
# [0.6641, 7.854, 5.2793, 7.854, 5.2793, 8.0201, 0.6641, 8.0201]
# "It was a remarkable year with tremendous talent," says Sharon Switzer who was featured on CP24
# [0.7083, 8.2085, 7.4043, 8.2085, 7.4043, 8.3746, 0.7083, 8.3746]
# earlier this September. "These were difficult decisions but the acclaim is well deserved. We thank our
# [0.6862, 8.3857, 7.5371, 8.3857, 7.5371, 8.5519, 0.6862, 8.5519]
# dedicated filmmakers for their contributions and continual support over the past ten years and look
# [0.6751, 8.5629, 7.36, 8.574, 7.36, 8.7402, 0.6751, 8.7402]
# forward to another ten years of TUFF."
# [0.6973, 8.7402, 3.2871, 8.7402, 3.2871, 8.9063, 0.6973, 8.9174]
# The full list of winners/awards is as follows:
# [0.6973, 9.1057, 3.6413, 9.1168, 3.6413, 9.2941, 0.6973, 9.283]
# VIEWERS' CHOICE AWARD - Presence of Time
# [0.6862, 9.4491, 4.0951, 9.4713, 4.0951, 9.6485, 0.6862, 9.6264]
# The award comes with a $500 prize from Pattison Onestop.
# [0.7083, 9.6485, 4.7148, 9.6596, 4.7148, 9.8258, 0.7083, 9.8258]
# Voting was open to everyone online from Sept 10 - 17, and we are happy to announce that the
# [1.0846, 9.8369, 7.5924, 9.8369, 7.5924, 10.003, 1.0846, 10.003]
# Viewers' Choice winner this year is The PRESENCE OF TIME by RAKIB BOBY from
# [1.1953, 10.003, 7.0059, 10.003, 7.0059, 10.1803, 1.1953, 10.1803]
# Bangladesh, who received 1047 online votes.
# [1.1842, 10.1913, 4.2721, 10.2024, 4.2721, 10.3797, 1.1842, 10.3686]
# TUFF 2016 Prizes selected by Toronto Film Commissioner Zaib Shaikh
# [0.6973, 1.1188, 5.8216, 1.1188, 5.8216, 1.3071, 0.6973, 1.3071]
# 1st PRIZE
# [0.6973, 1.4733, 1.4499, 1.4622, 1.4499, 1.6284, 0.7083, 1.6395]
# $3000 cash from Pattison Onestop and a permanent license for Storyboard Pro software from Toon
# [0.6973, 1.6616, 7.4375, 1.6616, 7.4375, 1.8389, 0.6862, 1.8389]
# Boom Animation.
# [0.6973, 1.8389, 1.8483, 1.8499, 1.8483, 2.0161, 0.6973, 2.005]
# A short that reaches well beyond the bounds of 60 seconds receives our top honours of 2016.
# [1.14, 2.0161, 7.515, 2.0272, 7.515, 2.2044, 1.14, 2.1934]
# The pain and confusion of a young boy caught between worlds is subtly yet powerfully told in a
# [1.1842, 2.2044, 7.5924, 2.2155, 7.5924, 2.3817, 1.1842, 2.3817]
# story turns a drive across the city into a heartbreaking journey. Our guest judge awarded 1st Prize
# [1.1732, 2.3927, 7.8027, 2.3927, 7.8027, 2.5589, 1.1732, 2.5589]
# to A NEW HOME by SPENCER RYERSON and PETER WIDDRINGTON.
# [1.1842, 2.5589, 6.209, 2.5589, 6.209, 2.7362, 1.1842, 2.7362]
# 2nd PRIZE
# [0.6862, 2.9023, 1.4831, 2.9023, 1.4831, 3.0796, 0.6862, 3.0796]
# $1,500 Cash from Pattison Onestop.
# [0.6862, 3.0906, 3.1875, 3.1017, 3.1875, 3.2679, 0.6862, 3.2568]
# In the film that wins 2nd Prize, a little girl runs late, in a subtle ode to everyday adventures and
# [1.1289, 3.2679, 7.5814, 3.279, 7.5814, 3.4451, 1.1289, 3.4451]
# small moments. Our guest judge would have been remiss not to honour the visual poetry on
# [1.1621, 3.4562, 7.4375, 3.4562, 7.4375, 3.6224, 1.1621, 3.6224]
# display in this elegant full-circle story about intersections, AUTUMN LEAVES by SAMAN
# [1.1842, 3.6334, 7.2272, 3.6224, 7.2272, 3.7996, 1.1842, 3.8107]
# HOSSEINPOUR! Saman is from Iran, but he has sent us a video.
# [1.1732, 3.8107, 5.6113, 3.8218, 5.6113, 3.9879, 1.1732, 3.9768]
# 3rd PRIZE
# [0.6973, 4.1652, 1.4499, 4.1652, 1.4388, 4.3424, 0.6973, 4.3424]
# $750 cash from Pattison Onestop.
# [0.6862, 4.431, 3.0104, 4.4421, 3.0104, 4.6083, 0.6862, 4.5972]
# 3rd Prize goes to a stop-motion short that playfully yet skillfully brings to life the creative process
# [1.151, 4.6193, 7.6921, 4.6304, 7.681, 4.7966, 1.151, 4.7966]
# behind independent animation, deftly showing how certain ideas can push through our
# [1.1621, 4.8077, 7.0391, 4.8077, 7.0391, 4.9738, 1.1621, 4.9738]
# imagination to become a reality. Our guest judge Zaib Shaikh was wowed by ELECTRIC DREAM
# [1.1732, 4.9738, 7.7917, 4.9627, 7.8027, 5.1511, 1.1732, 5.1621]
# CHUTE by WILLIAM ALLINSON.
# [1.1621, 5.1511, 3.4974, 5.1621, 3.4974, 5.3394, 1.1621, 5.3394]
# Honorable Mentions
# [0.6862, 5.5498, 2.1693, 5.5609, 2.1693, 5.7271, 0.6862, 5.716]
# Art by Mykyta Leskov from the Ukraine - Effects Suite from Red Giant Software
# [0.6862, 5.8379, 6.2865, 5.8379, 6.2865, 6.004, 0.6862, 6.0151]
# The Moment by Akilesh Kathamuthu from India - Magic Bullet Suite from Red Giant Software
# [0.6973, 6.0151, 7.2715, 6.004, 7.2715, 6.1923, 0.6973, 6.1923]
# Fireworks in the Ghetto by Shay Roddick from USA - Keying Suite from Red Giant Software
# [0.7083, 6.2034, 7.2272, 6.2034, 7.2272, 6.3807, 0.7083, 6.3807]
# 2016 Prizes selected by TUFF Founder Sharon Switzer & TUFF Programmer Angie Driscoll
# [0.6973, 6.7351, 7.2604, 6.7462, 7.2604, 6.9345, 0.6973, 6.9345]
# AWARD FOR BEST LOCAL FILM - Hope
# [0.6973, 7.145, 3.597, 7.145, 3.597, 7.3112, 0.6973, 7.3112]
# A $1,500 grant for Lighting and Grip Equipment from William F White International.
# [0.6973, 7.3223, 6.2754, 7.3223, 6.2754, 7.4995, 0.6973, 7.4995]
# A permanent license for Storyboard Pro software from Toon Boom Animation.
# [0.6973, 7.5106, 5.9212, 7.5106, 5.9212, 7.6989, 0.6973, 7.6878]
# A Canadian soldier and a young Afghan teach each other lessons that transcend language in this
# [1.151, 7.6878, 7.7695, 7.6878, 7.7695, 7.8761, 1.151, 7.8761]
# hopeful call for peace and understanding, education and encouragement, all set against a
# [1.1842, 7.8651, 7.2383, 7.8651, 7.2383, 8.0534, 1.1842, 8.0534]
# backdrop of conflict, both external and internal. Complex and sharply written, this year's AWARD
# [1.1732, 8.0423, 7.7142, 8.0423, 7.7142, 8.2195, 1.1732, 8.2306]
# FOR BEST LOCAL FILM belongs to SALAR PASHTOONYAR's short film HOPE!
# [1.1732, 8.2195, 6.6849, 8.2306, 6.6849, 8.4079, 1.1732, 8.4079]
# AWARD FOR BEST COMEDY - Dare to Dream?
# [0.6862, 8.5851, 4.1283, 8.5962, 4.1283, 8.7623, 0.6862, 8.7513]
# A permanent license for Harmony animation software from Toon Boom Animation.
# [0.6973, 8.7845, 6.209, 8.7845, 6.209, 8.9507, 0.6973, 8.9507]
# This year's AWARD FOR BEST COMEDY goes to a funny, fresh, and adorable film about a hero
# [1.1732, 8.9507, 7.7142, 8.9617, 7.7142, 9.1279, 1.1732, 9.1279]
# who dreams of playing professional soccer... despite his species. An idea is so strong and
# [1.1732, 9.139, 7.3158, 9.1279, 7.3158, 9.3051, 1.1732, 9.3051]
# amusing, that it makes you laugh while reconsidering all notions of discrimination, put your hands
# [1.1621, 9.3051, 7.7806, 9.3162, 7.7806, 9.5045, 1.1621, 9.4935]
# together for EUNSOO AHN's short DARE TO DREAM?!
# [1.151, 9.4935, 4.9805, 9.4935, 4.9805, 9.6707, 1.151, 9.6707]

# %% [markdown]
# # 成人內容偵測服務操作

# %%
from azure.cognitiveservices.vision.computervision import ComputerVisionClient
from msrest.authentication import CognitiveServicesCredentials

# Set API key.
subscription_key = '6ac220c316d24ff59df08be8d2096cf6'
# Set endpoint.
endpoint = 'https://vicbosstw.cognitiveservices.azure.com/'
# Call API
computervision_client = ComputerVisionClient(endpoint, CognitiveServicesCredentials(subscription_key))

remote_image_url = "https://raw.githubusercontent.com/Azure-Samples/cognitive-services-sample-data-files/master/ComputerVision/Images/landmark.jpg"

'''
Detect Adult or Racy Content - remote
This example detects adult or racy content in a remote image, then prints the adult/racy score.
The score is ranged 0.0 - 1.0 with smaller numbers indicating negative results.
'''
print("===== Detect Adult or Racy Content - remote =====")
# Select the visual feature(s) you want
remote_image_features = ["adult"]
# Call API with URL and features
detect_adult_results_remote = computervision_client.analyze_image(remote_image_url, remote_image_features)

# Print results with adult/racy score
print("Analyzing remote image for adult or racy content ... ")
print("Is adult content: {} with confidence {:.2f}".format(detect_adult_results_remote.adult.is_adult_content, detect_adult_results_remote.adult.adult_score * 100))
print("Has racy content: {} with confidence {:.2f}".format(detect_adult_results_remote.adult.is_racy_content, detect_adult_results_remote.adult.racy_score * 100))
# Out:
# ===== Detect Adult or Racy Content - remote =====
# Analyzing remote image for adult or racy content ...
# Is adult content: False with confidence 0.34
# Has racy content: False with confidence 0.49

# %%
from azure.cognitiveservices.vision.computervision import ComputerVisionClient
from msrest.authentication import CognitiveServicesCredentials

# Set API key.
subscription_key = '6ac220c316d24ff59df08be8d2096cf6'
# Set endpoint.
endpoint = 'https://vicbosstw.cognitiveservices.azure.com/'
# Call API
computervision_client = ComputerVisionClient(endpoint, CognitiveServicesCredentials(subscription_key))

remote_image_url = "https://lh3.googleusercontent.com/proxy/BS12ePIcJc0txe4utKPASuJnYG_XdK6PE7KNpBro1Z3rSpiem6BAwZzhVIJKr6lC_fR3XTYvb-6L6dL3wuodc2TXxnR44khPzbthvooAa_L8u14cbizZsugYloTVuO8KmYrhOhWx_stFgRc"

'''
Detect Adult or Racy Content - remote
This example detects adult or racy content in a remote image, then prints the adult/racy score.
The score is ranged 0.0 - 1.0 with smaller numbers indicating negative results.
'''
print("===== Detect Adult or Racy Content - remote =====")
# Select the visual feature(s) you want
remote_image_features = ["adult"]
# Call API with URL and features
detect_adult_results_remote = computervision_client.analyze_image(remote_image_url, remote_image_features)

# Print results with adult/racy score
print("Analyzing remote image for adult or racy content ... ")
print("Is adult content: {} with confidence {:.2f}".format(detect_adult_results_remote.adult.is_adult_content, detect_adult_results_remote.adult.adult_score * 100))
print("Has racy content: {} with confidence {:.2f}".format(detect_adult_results_remote.adult.is_racy_content, detect_adult_results_remote.adult.racy_score * 100))
# Out:
# ===== Detect Adult or Racy Content - remote =====
# Analyzing remote image for adult or racy content ...
# Is adult content: False with confidence 2.06
# Has racy content: False with confidence 3.36

# %%
https://m.media-amazon.com/images/M/MV5BZGM4MzRjYWItNDE5NC00YjgzLWJmYTctMzkwYTJhMGE4YTJjXkEyXkFqcGdeQXVyNDUzOTQ5MjY@._V1_.jpg

# %%
from azure.cognitiveservices.vision.computervision import ComputerVisionClient
from azure.cognitiveservices.vision.computervision.models import TextOperationStatusCodes
from msrest.authentication import CognitiveServicesCredentials
import time
from PIL import Image

# Set API key.
subscription_key = '2ed35306c8614c51ab8b9a880ae87f98'
# Set endpoint.
endpoint = 'https://vicbosstvv.cognitiveservices.azure.com/'
# Call API
computervision_client = ComputerVisionClient(endpoint, CognitiveServicesCredentials(subscription_key))


image_file = Image.open("lato1.jpg") # open colour image
image_file = image_file.convert('1') # convert image to black and white
image_file.save('result.jpg')

import os

# 指定圖檔
local_image_path = os.getcwd() + '/result.jpg'

# 讀取圖片
local_image = open(local_image_path, "rb")
'''
Batch Read File, recognize printed text - remote
This example will extract printed text in an image, then print results, line by line.
This API call can also recognize handwriting (not shown).
'''
print("===== Batch Read File - remote =====")
# Get an image with printed text
remote_image_printed_text_url = "https://raw.githubusercontent.com/Azure-Samples/cognitive-services-sample-data-files/master/ComputerVision/Images/printed_text.jpg"

# Call API with URL and raw response (allows you to get the operation location)
recognize_printed_results = computervision_client.batch_read_file_in_stream(local_image,  raw=True)

# Get the operation location (URL with an ID at the end) from the response
operation_location_remote = recognize_printed_results.headers["Operation-Location"]
# Grab the ID from the URL
operation_id = operation_location_remote.split("/")[-1]

# Call the "GET" API and wait for it to retrieve the results 
while True:
    get_printed_text_results = computervision_client.get_read_operation_result(operation_id)
    if get_printed_text_results.status not in ['NotStarted', 'Running']:
        break
    time.sleep(1)

# Print the detected text, line by line
if get_printed_text_results.status == TextOperationStatusCodes.succeeded:
    for text_result in get_printed_text_results.recognition_results:
        for line in  enumerate(text_result.lines):
            print(line.text)
            print('=======')
print()
# Out:
# ===== Batch Read File - remote =====
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-35fd81417c77> in <module>
#      52     for text_result in get_printed_text_results.recognition_results:
#      53         for line in  enumerate(text_result.lines):
# ---> 54             print(line.text)
#      55             print('=======')
#      56 print()
#
# AttributeError: 'tuple' object has no attribute 'text'
